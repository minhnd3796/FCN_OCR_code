# %%
import json

# %%
json_name = '/home/minhnd/FTI.Projects/FCN_OCR_dataset/address_json/841289701567_0901301893_310062583_1_2016030608245247.json'
with open(json_name) as json_file:
    data = json.load(json_file)
data
# Out:
# {'841289701567_0901301893_310062583_1_2016030608245247.jpg': {'base64_img_data': '',
#   'file_attributes': {},
#   'filename': '841289701567_0901301893_310062583_1_2016030608245247.jpg',
#   'fileref': '',
#   'regions': {'0': {'region_attributes': {'Name': '310062583'},
#     'shape_attributes': {'height': 52,
#      'name': 'rect',
#      'width': 296,
#      'x': 406,
#      'y': 115}},
#    '1': {'region_attributes': {'Name': 'NGUYỄN'},
#     'shape_attributes': {'height': 48,
#      'name': 'rect',
#      'width': 144,
#      'x': 386,
#      'y': 166}},
#    '10': {'region_attributes': {'Name': 'Phường'},
#     'shape_attributes': {'height': 45,
#      'name': 'rect',
#      'width': 140,
#      'x': 589,
#      'y': 392}},
#    '11': {'region_attributes': {'Name': '3'},
#     'shape_attributes': {'height': 45,
#      'name': 'rect',
#      'width': 45,
#      'x': 729,
#      'y': 392}},
#    '12': {'region_attributes': {'Name': 'Thị'},
# ...
